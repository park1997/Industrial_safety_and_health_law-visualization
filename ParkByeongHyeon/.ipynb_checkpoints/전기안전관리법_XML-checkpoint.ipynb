# %%
import requests
from urllib.request import urlopen
from urllib.parse import urlencode,unquote,quote_plus
import urllib
import lxml
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re

# %%
# 법령 XML 상세조회 (시행기준. target=eflaw)

#기본 url
url_base = " http://www.law.go.kr/DRF/lawService.do"

#조회 url 세부 설정
user_id = 'bmsong' #open API ID (bmsong@kau.ac.kr의 아이디 부분)
target = "eflaw" #법령 조회시
MST = "216209" #ID 또는 MST #전기안전관리법 MST 216209
#ID = "013718" 
            #ID 전기안전관리법 법령ID 013718 (설명에는 ID로 조회하면 현행법령이 조회된다는데, 
            #target을 eflaw로 하면 ID로 요청해도, MST로 요청해도 같은 것 같다.
Type = "XML" #출력 형태 : HTML 또는 XML

url_sub = "?" +\
        "OC=" + user_id +\
        "&target=" + target +\
        "&MST=" + MST +\
        "&type=" + Type

#최종 url
url = url_base + url_sub

print(url)

response = requests.get(url)

#(1) response.text 사용하는 방법
#soup = BeautifulSoup(response.text.encode('utf-8'), 'lxml-xml') #lxml-xml -> lxml 추가 설치 필요(Beautifulsoup과 별도로 설치)

#(2) response.content 사용하는 방법
soup = BeautifulSoup(response.content, 'lxml-xml') #lxml-xml -> lxml 추가 설치 필요(Beautifulsoup과 별도로 설치)


# soup
# Out:
#  http://www.law.go.kr/DRF/lawService.do?OC=bmsong&target=eflaw&MST=216209&type=XML

# %%
lc_basic_df = pd.DataFrame() #DataFrame for Law Content 

data = soup.find('법령ID') #MST 정보
lc_basic_df['법령ID'] = [data.get_text()]

data = soup.find('법종구분') 
lc_basic_df['법종구분']= [data.get_text()]

data = soup.find('법령명_한글') 
lc_basic_df['법령명']= [data.get_text()]

data = soup.find('시행일자')
lc_basic_df['시행일자'] = [data.get_text()]

data = soup.find('공포일자') 
lc_basic_df['공포일자']= [data.get_text()]

data = soup.find('소관부처') 
lc_basic_df['소관부처']= [data.get_text()]

lc_basic_df
# Out:
#      법령ID 법종구분      법령명      시행일자      공포일자     소관부처
# 0  013718   법률  전기안전관리법  20210401  20200331  산업통상자원부

# %%
# data = soup.find_all('조문단위')
# df_info = pd.DataFrame()
# info = []
# for i in data:
#     detail = {}
#     detail["index"] = np.nan
#     detail["조문제목"] = np.nan
#     detail["조문내용"] = np.nan
#     detail["항문내용"] = np.nan
#     detail["호문내용"] = np.nan
#     if i.find("조문여부").get_text() == "조문":
#         조문제목 = i.find("조문내용").get_text().strip().split(")")[0]+")"
#         detail["조문제목"] = 조문제목
#         if i.find("조문내용"):
#             조문내용 = i.find("조문내용").get_text().strip()[len(조문제목):-1].strip()
#             detail["조문내용"] = 조문내용
        
#         df_info = df_info.append(detail,ignore_index = True)
        
#         if i.find("항"):
#             for j in i.find_all("항"):
#                 if j.find("항내용"):
#                     detail["항문내용"] = j.항내용.get_text().strip()
#                     df_info = df_info.append(detail,ignore_index = True)
#                 if j.find("호내용"):
#                     for k in j.find_all("호내용"):
#                         detail["호문내용"] = k.get_text().strip()
#                         df_info = df_info.append(detail,ignore_index = True)
#                 detail["호문내용"] = np.nan
# df_info = df_info[["조문제목","조문내용","항문내용","호문내용"]]
# df_info
# Out:
#           조문제목                                               조문내용  \
# 0      제1조(목적)  이 법은 전기재해의 예방과 전기설비 안전관리에 필요한 사항을 규정함으로써 국민의 생...
# 1      제2조(정의)                           이 법에서 사용하는 용어의 뜻은 다음과 같다
# 2      제2조(정의)                           이 법에서 사용하는 용어의 뜻은 다음과 같다
# 3      제2조(정의)                           이 법에서 사용하는 용어의 뜻은 다음과 같다
# 4      제2조(정의)                           이 법에서 사용하는 용어의 뜻은 다음과 같다
# ..         ...                                                ...
# 288  제52조(과태료)
# 289  제52조(과태료)
# 290  제52조(과태료)
# 291  제52조(과태료)
# 292  제52조(과태료)
#
#                                                   항문내용  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 288    ② 다음 각 호의 어느 하나에 해당하는 자에게는 100만원 이하의 과태료를 부과한다.
# 289    ② 다음 각 호의 어느 하나에 해당하는 자에게는 100만원 이하의 과태료를 부과한다.
# 290    ② 다음 각 호의 어느 하나에 해당하는 자에게는 100만원 이하의 과태료를 부과한다.
# 291    ② 다음 각 호의 어느 하나에 해당하는 자에게는 100만원 이하의 과태료를 부과한다.
# 292  ③ 제1항 및 제2항에 따른 과태료는 대통령령으로 정하는 바에 따라 산업통상자원부장...
#
#                                                   호문내용
# 0                                                  NaN
# 1                                                  NaN
# 2    1. "전기안전관리"란 국민의 생명과 재산을 보호하기 위하여 전기설비의 공사·유지·...
# 3    2. "전기재해"란 전기화재, 감전사고 등으로 인하여 사람의 생명과 재산의 피해가 ...
# 4           3. "전기사업자"란 「전기사업법」 제2조제2호에 따른 전기사업자를 말한다.
# ..                                                 ...
# 288              9. 제25조제1항제2호를 위반하여 안전시공교육을 받지 아니한 사람
# 289    10. 제25조제4항을 위반하여 전기안전교육을 받지 아니한 사람을 해임하지 아니한 자
# 290  11. 제25조제5항을 위반하여 안전시공교육을 받지 아니한 사람의 시공관리책임자 지...
# 291  12. 제26조제1항제4호에 따른 등록을 하지 아니하거나 같은 조 제2항에 따른 변...
# 292                                                NaN
#
# [293 rows x 4 columns]

# %%
data = soup.find_all('조문단위')
df_info = pd.DataFrame()
info = []
for i in data:
    info_str = ""
    if i.find("조문여부").get_text() == "조문":
        info_str += i.조문내용.get_text().strip()
        if i.항:
            hang_nums = i.find_all("항번호")
            ho_nums = i.find_all("호번호")
            for idx, p in enumerate(i.find_all("호내용")):
                info_str += p.get_text().split(ho_nums[idx].get_text())[1].strip()
            for hang_idx, k in enumerate(i.find_all("항내용")):
                info_str += k.get_text().strip().split(hang_nums[hang_idx].get_text())[1].strip()
                for ho_idx ,j in enumerate(i.find_all("호내용")):
                    info_str += j.get_text().strip().split(ho_nums[ho_idx].get_text())[1].strip()
        info.append(info_str)
df_info["조내용"] = info
df_info
# Out:
#                                                   조내용
# 0   제1조(목적) 이 법은 전기재해의 예방과 전기설비 안전관리에 필요한 사항을 규정함으...
# 1   제2조(정의) 이 법에서 사용하는 용어의 뜻은 다음과 같다."전기안전관리"란 국민의...
# 2   제3조(국가의 책무) 국가는 국민이 전기재해로부터 안전성을 확보할 수 있도록 전기안...
# 3   제4조(다른 법률과의 관계) 전기안전관리에 대하여 다른 법률에 특별한 규정이 있는 ...
# 4   제5조(전기안전관리 기본계획 수립 등)전기안전관리에 관한 중·장기 정책에 관한 사항...
# 5   제6조(전기안전자문기구의 설치)산업통상자원부장관은 전기안전관리 정책을 원활하게 수립...
# 6   제7조(전기안전관리 관련 기술의 연구·개발)제30조에 따른 한국전기안전공사(이하 "...
# 7   제8조(자가용전기설비의 공사계획의 인가 또는 신고)자가용전기설비의 설치공사 또는 변...
# 8   제9조(사용전검사) 제8조에 따라 자가용전기설비의 설치공사 또는 변경공사를 한 자는...
# 9   제10조(자가용전기설비의 임시사용)산업통상자원부장관 또는 시·도지사는 제9조에 따른...
# 10  제11조(정기검사)전기사업자 및 자가용전기설비의 소유자 또는 점유자는 산업통상자원부...
# 11  제12조(일반용전기설비의 점검)기술기준에 적합하도록 하기 위하여 필요한 조치의 내용...
# 12  제13조(여러 사람이 이용하는 시설 등에 대한 전기안전점검)「청소년활동 진흥법」에 ...
# 13  제14조(공동주택 등의 안전점검)「주택법」 제2조제3호에 따른 공동주택의 세대「전통...
# 14  제15조(특별안전점검 및 응급조치)태풍·폭설 등의 재난으로 전기사고가 발생하거나 발...
# 15  제16조(전기재해 예방을 위한 안전조치)산업통상자원부장관은 전기재해 예방을 위하여 ...
# 16  제17조(안전등급 지정 등)제12조제2항에 따라 전기설비의 수리·개조 등 필요한 조...
# 17  제18조(검사·점검의 방법·절차 등) 산업통상자원부장관은 전기설비의 안전성 확보를 ...
# 18  제19조(전기설비의 유지) 자가용전기설비 또는 일반용전기설비의 소유자나 점유자는 전...
# 19  제20조(적합명령) 산업통상자원부장관 또는 시·도지사는 다음 각 호의 어느 하나에 ...
# 20  제21조(정보의 공개)산업통상자원부장관 또는 시·도지사는 대통령령으로 정하는 바에 ...
# 21  제22조(전기안전관리자의 선임 등)전기안전관리업무를 전문으로 하는 자로서 자본금, ...
# 22  제23조(전기안전관리자의 선임 및 해임신고 등)제22조제1항부터 제4항까지의 규정에...
# 23  제24조(전기안전관리자의 성실의무 등)전기안전관리자는 제22조제6항에 따른 직무를 ...
# 24  제25조(전기안전관리자의 교육 등)전기안전관리자: 전기설비의 유지 및 운용에 관한 ...
# 25  제26조(전기안전관리업무를 전문으로 하는 자 등의 등록)제22조제2항제1호에 따라 ...
# 26  제27조(등록의 결격사유 및 취소 등)피성년후견인파산선고를 받고 복권되지 아니한 자...
# 27  제28조(청문) 산업통상자원부장관 또는 시·도지사는 제27조제2항에 따라 등록을 취...
# 28  제29조(전기안전관리업무에 대한 실태조사 등)산업통상자원부장관은 매년 1회 이상 전...
# 29  제30조(한국전기안전공사의 설립)전기로 인한 재해를 예방하기 위하여 전기안전에 관한...
# 30  제31조(안전공사의 운영 등) 안전공사의 운영에 필요한 경비는 다음 각 호의 재원으...
# 31  제32조(임원)안전공사의 임원은 사장 1명, 이사 8명 이내와 감사 1명으로 한다....
# 32  제33조(사업) 안전공사는 다음 각 호의 사업을 한다.전기안전에 관한 조사 및 연구...
# 33  제34조(다른 법률과의 관계) 안전공사에 관하여 이 법 및 「공공기관의 운영에 관한...
# 34  제35조(감독) 산업통상자원부장관은 안전공사의 업무 중 다음 각 호의 어느 하나에 ...
# 35  제36조(유사명칭의 사용 금지) 이 법에 따른 안전공사가 아닌 자는 한국전기안전공사...
# 36  제37조(비밀 유지의 의무) 안전공사의 임직원이나 그 직에 있었던 사람은 직무와 관...
# 37  제38조(전기안전종합정보시스템의 구축·운영 등)산업통상자원부장관은 전기안전관리에 관...
# 38  제39조(보고)산업통상자원부장관은 산업통상자원부령으로 정하는 바에 따라 전기설비의 ...
# 39  제40조(중대한 사고의 통보·조사)안전공사산업통상자원부령으로 정하는 기술인력 및 장...
# 40  제41조(전기재해통계의 작성)산업통상자원부장관은 전기안전관리 정책을 효과적으로 수립...
# 41  제42조(수수료 등)제9조 및 제11조에 따른 검사를 받으려는 자제13조에 따른 전...
# 42  제43조(권한의 위임·위탁)제8조제2항에 따른 자가용전기설비의 공사계획의 신고 및 ...
# 43  제44조(관리·감독)산업통상자원부장관 또는 시·도지사는 전력기술인단체 또는 공사업자...
# 44  제45조(벌칙 적용에서 공무원 의제) 산업통상자원부장관 또는 시·도지사가 제43조제...
# 45  제46조(벌칙) 다음 각 호의 어느 하나에 해당하는 자는 2년 이하의 징역 또는 2...
# 46  제47조(벌칙) 다음 각 호의 어느 하나에 해당하는 자는 1년 이하의 징역 또는 1...
# 47  제48조(벌칙) 제22조제1항부터 제4항까지의 규정을 위반하여 전기안전관리자를 선임...
# 48  제49조(벌칙) 다음 각 호의 어느 하나에 해당하는 자는 300만원 이하의 벌금에 ...
# 49  제50조(벌칙) 제11조에 따른 검사를 거부·방해 또는 기피한 자는 100만원 이하...
# 50  제51조(양벌규정) 법인의 대표자나 법인 또는 개인의 대리인, 사용인, 그 밖의 종...
# 51  제52조(과태료)제12조제5항(제14조제2항에서 준용하는 경우를 포함한다)에 따른 ...

# %%
df_info.to_excel('전기안전관리법.xlsx',index = False)
